# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
pd.set_option('display.max_columns', None)
file = r'C:\Users\PythonFiles\PYcharm\amazon_sales\artifacts\data.csv'
file1 = 'SALESDATA.xlsx'

# %%
df = pd.read_csv(file)
df.tail()
# Out:
#        Discount Amount                          Item  List Price  \
# 65276         272.5230  Better Fancy Canned Sardines     39.1545
# 65277         548.2520             Monarch Spaghetti     40.3128
# 65278          26.2588                Moms Cole Slaw     27.3537
# 65279         447.6400          Swell Canned Peaches     14.2560
# 65280          15.7200             Walrus Chardonnay      0.3929
#
#        Sales Amount  Sales Amount Based on List Price  Sales Cost Amount  \
# 65276       6540.36                         6812.8830            2969.78
# 65277      13158.10                        13706.3520            6424.27
# 65278        630.23                          656.4888             421.22
# 65279      10743.32                        11190.9600            6258.02
# 65280        377.18                          392.9000             340.10
#
#        Sales Margin Amount  Sales Price  Sales Quantity  Year Month
# ...

# %%
pd.concat([df, df], ignore_index=True, axis=0)
# Out:
#         Discount Amount                          Item  List Price  \
# 0              158.0400     Nationeel Salted Pretzels    181.4400
# 1              420.9000          Ebony Prepared Salad    966.4400
# 2              663.4100          Thresher Spicy Mints    507.7500
# 3              179.4500  Big Time Frozen Cheese Pizza    412.0300
# 4             1516.5200     Red Spade Turkey Hot Dogs   1160.7000
# ...                 ...                           ...         ...
# 130557         272.5230  Better Fancy Canned Sardines     39.1545
# 130558         548.2520             Monarch Spaghetti     40.3128
# 130559          26.2588                Moms Cole Slaw     27.3537
# 130560         447.6400          Swell Canned Peaches     14.2560
# 130561          15.7200             Walrus Chardonnay      0.3929
#
#         Sales Amount  Sales Amount Based on List Price  Sales Cost Amount  \
# 0             204.84                          362.8800              59.73
# ...
